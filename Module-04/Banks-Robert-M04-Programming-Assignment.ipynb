# %% [markdown]
# # Programming Assignment - Modules and Databases
#
# **TABLE OF CONTENTS**
#
# - [11.1](#111-and-112)
# - [16.8](#168---booksdb)

# %% [markdown]
# ## 11.1 AND 11.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 16.8 - books.db

# %% [markdown]
# ![image.png](attachment:image.png)
